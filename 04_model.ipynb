# %%
# !pip uninstall -y sagemaker sagemaker-core sagemaker-train sagemaker-serve sagemaker-mlops sagemaker-studio
# Out:
# WARNING: Skipping sagemaker as it is not installed.
# WARNING: Skipping sagemaker-core as it is not installed.
# WARNING: Skipping sagemaker-train as it is not installed.
# WARNING: Skipping sagemaker-serve as it is not installed.
# WARNING: Skipping sagemaker-mlops as it is not installed.
# WARNING: Skipping sagemaker-studio as it is not installed.

# %%
# !pip install "sagemaker-core==1.0.78" --quiet

# %%
# !pip install "sagemaker==2.232.2" --no-deps --quiet

# %%
# !pip install scikit-learn sentence-transformers
# Out:
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.12/site-packages (1.7.2)
# Requirement already satisfied: sentence-transformers in /opt/conda/lib/python3.12/site-packages (5.5.1)
# Requirement already satisfied: numpy>=1.22.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /opt/conda/lib/python3.12/site-packages (from sentence-transformers) (4.57.6)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/conda/lib/python3.12/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.29.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.34.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/conda/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.5,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.12/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.26.20)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.12/site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.20)

# %%
# !pip install tf-keras
# Out:
# Collecting tf-keras
#   Using cached tf_keras-2.21.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow<2.22,>=2.21 (from tf-keras)
#   Using cached tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.2.0)
# Collecting libclang>=13.0.0 (from tensorflow<2.22,>=2.21->tf-keras)
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt_einsum>=2.3.2 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (6.31.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.34.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.73.1)
# Requirement already satisfied: keras>=3.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.14.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.26.4)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow<2.22,>=2.21->tf-keras)
#   Using cached h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (1.26.20)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (2026.5.20)
# Requirement already satisfied: rich in /opt/conda/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (14.3.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.2)
# Using cached tf_keras-2.21.0-py3-none-any.whl (1.7 MB)
# Using cached tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl (572.6 MB)
# Using cached h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
# Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
# Installing collected packages: libclang, h5py, tensorflow, tf-keras
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [libclang]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [libclang]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [libclang]
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.16.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [libclang]
#     Uninstalling h5py-3.16.0:
#       Successfully uninstalled h5py-3.16.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [libclang]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [h5py]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [h5py]
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.19.1
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [h5py]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#     Uninstalling tensorflow-2.19.1:
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#       Successfully uninstalled tensorflow-2.19.1
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [tensorflow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [tf-keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [tf-keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [tf-keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [tf-keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [tf-keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [tf-keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [tf-keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [tf-keras]
# Successfully installed h5py-3.14.0 libclang-18.1.1 tensorflow-2.19.1 tf-keras-2.21.0

# %%
import pandas as pd
import numpy as np
import boto3
import sagemaker

from sagemaker.estimator import Estimator
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score, classification_report
# from sentence_transformers import SentenceTransformer
import os

# Initialize SageMaker session and roles
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
region = sagemaker_session.boto_region_name
bucket = 'aai540-project-data-yelp-160827082121-ap-southeast-2-an'
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# ## Load Data from S3 Splits

# %%
print("Loading train, validation, and test splits from S3...")
base_s3_uri = f"s3://{bucket}/data/splits"

# Assuming the files were saved as Parquet. Change to read_csv if necessary.
df_train = pd.read_parquet(f"{base_s3_uri}/train/")
df_val = pd.read_parquet(f"{base_s3_uri}/validation/")
df_test = pd.read_parquet(f"{base_s3_uri}/test/")

print(f"Train: {len(df_train):,} | Val: {len(df_val):,} | Test: {len(df_test):,}")
# Out:
# Loading train, validation, and test splits from S3...
# Train: 125,970 | Val: 31,492 | Test: 31,493

# %% [markdown]
# ## Set Up the Benchmark Model

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125970 entries, 0 to 125969
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   review_id              125970 non-null  object
#  1   text                   125970 non-null  object
#  2   text_char_length       125970 non-null  int64
#  3   text_word_count        125970 non-null  int64
#  4   review_useful_votes    125970 non-null  int64
#  5   review_funny_votes     125970 non-null  int64
#  6   review_cool_votes      125970 non-null  int64
#  7   business_avg_stars     125970 non-null  float64
#  8   business_review_count  125970 non-null  int64
#  9   primary_category       125970 non-null  object
#  10  business_state         125970 non-null  object
#  11  user_avg_stars         125970 non-null  float64
#  12  user_review_count      125970 non-null  int64
#  13  is_elite               125970 non-null  int64
#  14  sentiment_label        125970 non-null  int64
#  15  eventtime              125970 non-null  float64
#  16  write_time             125970 non-null  object
#  17  api_invocation_time    125970 non-null  object
#  18  is_deleted             125970 non-null  bool
# dtypes: bool(1), float64(3), int64(9), object(6)
# memory usage: 17.4+ MB

# %%
print("\n--- Training Benchmark Model (Logistic Regression) ---")

numerical_features = [
    'text_char_length', 
    'is_elite', 
    'review_useful_votes', 
    'review_funny_votes', 
    'review_cool_votes'
]

# Extract features and target, filling any potential NaNs
X_bench_train = df_train[numerical_features].fillna(0)
y_bench_train = df_train['sentiment_label']

X_bench_test = df_test[numerical_features].fillna(0)
y_bench_test = df_test['sentiment_label']

# Train baseline Logistic Regression
benchmark_model = LogisticRegression(max_iter=1000, class_weight='balanced')
benchmark_model.fit(X_bench_train, y_bench_train)

# Evaluate baseline
bench_preds = benchmark_model.predict(X_bench_test)
bench_f1 = f1_score(y_bench_test, bench_preds, average='macro')
bench_acc = accuracy_score(y_bench_test, bench_preds)

print(f"Benchmark Accuracy: {bench_acc:.4f}")
print(f"Benchmark Macro F1: {bench_f1:.4f}")
# Out:
# --- Training Benchmark Model (Logistic Regression) ---
# Benchmark Accuracy: 0.7223
# Benchmark Macro F1: 0.6708

# %% [markdown]
# ## Preprocessing for the XGBoost Model (Text Embeddings)

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /opt/conda/lib/python3.12/site-packages (2.2.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from datasets) (15.0.2)
# Requirement already satisfied: dill in /opt/conda/lib/python3.12/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.12/site-packages (from datasets) (2.34.2)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.12/site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.12/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.12/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/conda/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->datasets) (2026.3.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.12/site-packages (from datasets) (3.13.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /opt/conda/lib/python3.12/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from datasets) (26.2)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.12/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.29.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (1.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.15.0)
# Requirement already satisfied: urllib3>=1.25.10 in /opt/conda/lib/python3.12/site-packages (from responses<0.19->datasets) (2.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.19.0->datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.19.0->datasets) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.12/site-packages (from requests>=2.19.0->datasets) (2026.5.20)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp->datasets) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
pip install --force-reinstall tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting packaging (from tensorflow)
#   Using cached packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Using cached protobuf-7.35.0-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting setuptools (from tensorflow)
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting six>=1.12.0 (from tensorflow)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting typing_extensions>=3.6.6 (from tensorflow)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Using cached wrapt-2.2.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.81.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.7 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Using cached keras-3.14.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting numpy>=1.26.0 (from tensorflow)
#   Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Using cached h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow)
#   Using cached charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow)
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting urllib3<3,>=1.26 (from requests<3,>=2.21.0->tensorflow)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests<3,>=2.21.0->tensorflow)
#   Using cached certifi-2026.5.20-py3-none-any.whl.metadata (2.5 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.12.0->tensorflow)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Using cached optree-0.19.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (32 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.12.0->tensorflow)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->keras>=3.12.0->tensorflow)
#   Using cached pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl (572.6 MB)
# Using cached grpcio-1.81.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.8 MB)
# Using cached h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
# Using cached ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
# Using cached protobuf-7.35.0-cp310-abi3-manylinux2014_x86_64.whl (327 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
# Using cached idna-3.18-py3-none-any.whl (65 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached wheel-0.47.0-py3-none-any.whl (32 kB)
# Using cached certifi-2026.5.20-py3-none-any.whl (134 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached keras-3.14.1-py3-none-any.whl (1.6 MB)
# Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
# Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached packaging-26.2-py3-none-any.whl (100 kB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Using cached wrapt-2.2.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (169 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Using cached optree-0.19.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (457 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached pygments-2.20.0-py3-none-any.whl (1.2 MB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, urllib3, typing_extensions, termcolor, six, setuptools, pygments, protobuf, packaging, opt_einsum, numpy, mdurl, idna, gast, charset_normalizer, certifi, absl-py, wheel, requests, optree, ml_dtypes, markdown-it-py, h5py, grpcio, google_pasta, rich, astunparse, keras, tensorflow
#   Attempting uninstall: namex
#     Found existing installation: namex 0.1.0
#     Uninstalling namex-0.1.0:
#       Successfully uninstalled namex-0.1.0
#   Attempting uninstall: libclang
#     Found existing installation: libclang 18.1.1
#     Uninstalling libclang-18.1.1:
#       Successfully uninstalled libclang-18.1.1
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/32 [libclang]
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/32 [libclang]
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 25.12.19
#     Uninstalling flatbuffers-25.12.19:
#       Successfully uninstalled flatbuffers-25.12.19
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/32 [libclang]
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.2.1
#     Uninstalling wrapt-2.2.1:
#       Successfully uninstalled wrapt-2.2.1
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/32 [libclang]
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.7.0
#     Uninstalling urllib3-2.7.0:
#       Successfully uninstalled urllib3-2.7.0
#    ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/32 [urllib3]
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#    ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/32 [urllib3]
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/32 [typing_extensions]
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/32 [typing_extensions]
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/32 [typing_extensions]
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/32 [typing_extensions]
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/32 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.15.0
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/32 [typing_extensions]
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.3.0
#     Uninstalling termcolor-3.3.0:
#       Successfully uninstalled termcolor-3.3.0
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/32 [typing_extensions]
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/32 [six]
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/32 [six]
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/32 [six]
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/32 [six]
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/32 [six]
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: setuptools
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/32 [six]
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#       Successfully uninstalled setuptools-82.0.1
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#   Attempting uninstall: pygments
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#     Found existing installation: Pygments 2.20.0
#     Uninstalling Pygments-2.20.0:
#       Successfully uninstalled Pygments-2.20.0
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/32 [setuptools]
#    ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/32 [pygments]
#    ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/32 [pygments]
#    ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/32 [pygments]
#    ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/32 [pygments]
#   Attempting uninstall: protobuf
#    ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/32 [pygments]
#     Found existing installation: protobuf 7.35.0
#     Uninstalling protobuf-7.35.0:
#       Successfully uninstalled protobuf-7.35.0
#    ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/32 [protobuf]
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.2
#     Uninstalling packaging-26.2:
#       Successfully uninstalled packaging-26.2
#    ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/32 [packaging]
#   Attempting uninstall: opt_einsum
#    ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/32 [packaging]
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
#    ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/32 [packaging]
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#    ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/32 [packaging]
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 13/32 [numpy]
#   Attempting uninstall: mdurl
#     Found existing installation: mdurl 0.1.2
#     Uninstalling mdurl-0.1.2:
#       Successfully uninstalled mdurl-0.1.2
#   Attempting uninstall: idna
#    ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━ 15/32 [idna]
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
#    ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━ 15/32 [idna]
#   Attempting uninstall: gast
#     Found existing installation: gast 0.7.0
#     Uninstalling gast-0.7.0:
#       Successfully uninstalled gast-0.7.0
#   Attempting uninstall: charset_normalizer
#    ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━ 15/32 [idna]
#     Found existing installation: charset-normalizer 3.4.7
#     Uninstalling charset-normalizer-3.4.7:
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 17/32 [charset_normalizer]
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 17/32 [charset_normalizer]
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 17/32 [charset_normalizer]
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 17/32 [charset_normalizer]
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 17/32 [charset_normalizer]
#       Successfully uninstalled charset-normalizer-3.4.7
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 17/32 [charset_normalizer]
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2026.5.20
#     Uninstalling certifi-2026.5.20:
#       Successfully uninstalled certifi-2026.5.20
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 17/32 [charset_normalizer]
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 2.4.0
#     Uninstalling absl-py-2.4.0:
#       Successfully uninstalled absl-py-2.4.0
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 17/32 [charset_normalizer]
#   Attempting uninstall: wheel
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 17/32 [charset_normalizer]
#     Found existing installation: wheel 0.47.0
#     Uninstalling wheel-0.47.0:
#       Successfully uninstalled wheel-0.47.0
#   Attempting uninstall: requests
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 20/32 [wheel]
#     Found existing installation: requests 2.34.2
#     Uninstalling requests-2.34.2:
#       Successfully uninstalled requests-2.34.2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 20/32 [wheel]
#   Attempting uninstall: optree
#     Found existing installation: optree 0.19.1
#     Uninstalling optree-0.19.1:
#       Successfully uninstalled optree-0.19.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 20/32 [wheel]
#   Attempting uninstall: ml_dtypes
#     Found existing installation: ml_dtypes 0.5.4
#     Uninstalling ml_dtypes-0.5.4:
#       Successfully uninstalled ml_dtypes-0.5.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━ 23/32 [ml_dtypes]
#   Attempting uninstall: markdown-it-py
#     Found existing installation: markdown-it-py 4.2.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━ 23/32 [ml_dtypes]
#     Uninstalling markdown-it-py-4.2.0:
#       Successfully uninstalled markdown-it-py-4.2.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━ 23/32 [ml_dtypes]
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.14.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 24/32 [markdown-it-py]
#     Uninstalling h5py-3.14.0:
#       Successfully uninstalled h5py-3.14.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 24/32 [markdown-it-py]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 25/32 [h5py]
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.81.0
#     Uninstalling grpcio-1.81.0:
#       Successfully uninstalled grpcio-1.81.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 25/32 [h5py]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 26/32 [grpcio]
#   Attempting uninstall: google_pasta
#     Found existing installation: google-pasta 0.2.0
#     Uninstalling google-pasta-0.2.0:
#       Successfully uninstalled google-pasta-0.2.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 26/32 [grpcio]
#   Attempting uninstall: rich
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━ 27/32 [google_pasta]
#     Found existing installation: rich 14.3.4
#     Uninstalling rich-14.3.4:
#       Successfully uninstalled rich-14.3.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━ 27/32 [google_pasta]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 28/32 [rich]
#   Attempting uninstall: astunparse
#     Found existing installation: astunparse 1.6.3
#     Uninstalling astunparse-1.6.3:
#       Successfully uninstalled astunparse-1.6.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 28/32 [rich]
#   Attempting uninstall: keras
#     Found existing installation: keras 3.14.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 28/32 [rich]
#     Uninstalling keras-3.14.1:
#       Successfully uninstalled keras-3.14.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 30/32 [keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 30/32 [keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 30/32 [keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 30/32 [keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 30/32 [keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 30/32 [keras]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 30/32 [keras]
#   Attempting uninstall: tensorflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 30/32 [keras]
#     Found existing installation: tensorflow None
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 30/32 [keras]error: uninstall-no-record-file
#
# × Cannot uninstall tensorflow None
# ╰─> The package's contents are unknown: no RECORD file was found for tensorflow.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps tensorflow==2.19.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━ 31/32 [tensorflow]
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --force-reinstall --no-deps tensorflow==2.19.1
# Out:
# Collecting tensorflow==2.19.1
#   Using cached tensorflow-2.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Using cached tensorflow-2.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (645.0 MB)
# Installing collected packages: tensorflow
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow None
# error: uninstall-no-record-file
#
# × Cannot uninstall tensorflow None
# ╰─> The package's contents are unknown: no RECORD file was found for tensorflow.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps tensorflow==2.19.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pyarrow==15.0.2
# Out:
# Requirement already satisfied: pyarrow==15.0.2 in /opt/conda/lib/python3.12/site-packages (15.0.2)
# Requirement already satisfied: numpy<2,>=1.16.6 in /opt/conda/lib/python3.12/site-packages (from pyarrow==15.0.2) (1.26.4)

# %%
import importlib.metadata

# Save the original function
_original_version = importlib.metadata.version

# Define a safe wrapper
def safe_version(package_name):
    try:
        ver = _original_version(package_name)
        # If the metadata is broken and returns None, fake it so the parser doesn't crash
        return ver if ver is not None else "0.0.0"
    except importlib.metadata.PackageNotFoundError:
        # Let the normal missing package error pass through
        raise

# Apply the patch
importlib.metadata.version = safe_version

from sentence_transformers import SentenceTransformer

# %%
print("\n--- Generating Text Embeddings (all-MiniLM-L6-v2) ---")
# Initialize the embedding model
embedder = SentenceTransformer('all-MiniLM-L6-v2')

def prepare_xgb_data(df):
    """Encodes text and combines with numerical features for XGBoost."""
    # 1. Generate text embeddings (converts text to 384-dimensional vectors)
    # Note: Depending on instance size, this might take a few minutes for 315k rows!
    embeddings = embedder.encode(df['text'].tolist(), show_progress_bar=True)
    df_embeddings = pd.DataFrame(embeddings, index=df.index)
    
    # 2. Isolate target and numerical features (UPDATED COLUMN NAMES)
    y = df['sentiment_label']
    numerical_cols = [
        'text_char_length', 
        'is_elite', 
        'review_useful_votes', 
        'review_funny_votes', 
        'review_cool_votes'
    ]
    X_num = df[numerical_cols].fillna(0)
    
    # 3. Concatenate (Target must be the first column for SageMaker XGBoost)
    final_df = pd.concat([y, X_num, df_embeddings], axis=1)
    return final_df

# Apply transformation
print("Processing Training Data...")
train_xgb = prepare_xgb_data(df_train)
print("Processing Validation Data...")
val_xgb = prepare_xgb_data(df_val)
print("Processing Test Data...")
test_xgb = prepare_xgb_data(df_test)

# Save processed data locally then upload to S3 for SageMaker Training
print("\nUploading processed data to S3 for SageMaker...")

# SageMaker XGBoost requires header=False and index=False
train_xgb.to_csv('train_xgb.csv', header=False, index=False)
val_xgb.to_csv('val_xgb.csv', header=False, index=False)

s3_train_path = sagemaker_session.upload_data('train_xgb.csv', bucket=bucket, key_prefix='data/sagemaker_input/train')
s3_val_path = sagemaker_session.upload_data('val_xgb.csv', bucket=bucket, key_prefix='data/sagemaker_input/validation')




print(f"Training data uploaded to: {s3_train_path}")
print(f"Validation data uploaded to: {s3_val_path}")
# Out:
# --- Generating Text Embeddings (all-MiniLM-L6-v2) ---
# Processing Training Data...
# Batches:   0%|          | 0/3937 [00:00<?, ?it/s]
# Processing Validation Data...
# Batches:   0%|          | 0/985 [00:00<?, ?it/s]
# Processing Test Data...
# Batches:   0%|          | 0/985 [00:00<?, ?it/s]
# Uploading processed data to S3 for SageMaker...
# Training data uploaded to: s3://aai540-project-data-yelp-160827082121-ap-southeast-2-an/data/sagemaker_input/train/train_xgb.csv
# Validation data uploaded to: s3://aai540-project-data-yelp-160827082121-ap-southeast-2-an/data/sagemaker_input/validation/val_xgb.csv

# %%
test_xgb.to_csv('test_xgb.csv', header=False, index=False)
# Upload the test set to S3
s3_test_path = sagemaker_session.upload_data(
    'test_xgb.csv', 
    bucket=bucket, 
    key_prefix='data/sagemaker_input/test'
)

print(f"Test data uploaded to: {s3_test_path}")
# Out:
# Test data uploaded to: s3://aai540-project-data-yelp-160827082121-ap-southeast-2-an/data/sagemaker_input/test/test_xgb.csv

# %% [markdown]
# ## Build and Train SageMaker XGBoost Model

# %%
s3_train_path = 's3://aai540-project-data-yelp-160827082121-ap-southeast-2-an/data/sagemaker_input/train/train_xgb.csv'
s3_val_path = 's3://aai540-project-data-yelp-160827082121-ap-southeast-2-an/data/sagemaker_input/validation/val_xgb.csv'

s3_test_path = 's3://aai540-project-data-yelp-160827082121-ap-southeast-2-an/data/sagemaker_input/test/test_xgb.csv'

# %%
print(region)
# Out:
# ap-southeast-2

# %%
import boto3
import sagemaker

print("\n--- Configuring SageMaker XGBoost Estimator ---")

# Force us-east-1 where ml.t3.medium is supported
region = 'us-east-1'
boto_session = boto3.Session(region_name=region)
sagemaker_session = sagemaker.Session(boto_session=boto_session)
role = sagemaker.get_execution_role(sagemaker_session=sagemaker_session)

container = sagemaker.image_uris.retrieve("xgboost", region, "1.7-1")

xgb_estimator = sagemaker.estimator.Estimator(
    image_uri=container,
    role=role,
    instance_count=1,
    instance_type='ml.t3.medium',
    output_path=f's3://{bucket}/models/xgboost-sentiment/',
    sagemaker_session=sagemaker_session
)

xgb_estimator.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    objective='binary:logistic',
    scale_pos_weight=2.92,
    num_round=100
)

s3_input_train = sagemaker.inputs.TrainingInput(s3_data=s3_train_path, content_type='csv')
s3_input_val = sagemaker.inputs.TrainingInput(s3_data=s3_val_path, content_type='csv')

print("Starting SageMaker Training Job...")
xgb_estimator.fit({'train': s3_input_train, 'validation': s3_input_val})
# Out:
# --- Configuring SageMaker XGBoost Estimator ---
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2026-06-06-17-53-00-793
# Starting SageMaker Training Job...
# ERROR:sagemaker:Please check the troubleshooting guide for common errors: https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-python-sdk-troubleshooting.html#sagemaker-python-sdk-troubleshooting-create-training-job
# ---------------------------------------------------------------------------
# ResourceLimitExceeded                     Traceback (most recent call last)
# Cell In[26], line 38
#      35 s3_input_val = sagemaker.inputs.TrainingInput(s3_data=s3_val_path, content_type='csv')
#      37 print("Starting SageMaker Training Job...")
# ---> 38 xgb_estimator.fit({'train': s3_input_train, 'validation': s3_input_val})
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/workflow/pipeline_context.py:346, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     342         return context
#     344     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 346 return run_func(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/estimator.py:1369, in EstimatorBase.fit(self, inputs, wait, logs, job_name, experiment_config)
#    1366 self._prepare_for_training(job_name=job_name)
#    1368 experiment_config = check_and_get_run_experiment_config(experiment_config)
# -> 1369 self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#    1370 self.jobs.append(self.latest_training_job)
#    1371 forward_to_mlflow_tracking_server = False
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/estimator.py:2498, in _TrainingJob.start_new(cls, estimator, inputs, experiment_config)
#    2495 train_args = cls._get_train_args(estimator, inputs, experiment_config)
#    2497 logger.debug("Train args after processing defaults: %s", train_args)
# -> 2498 estimator.sagemaker_session.train(**train_args)
#    2500 return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:1055, in Session.train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, training_image_config, infra_check_config, container_entry_point, container_arguments, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config, environment, retry_strategy, remote_debug_config, session_chaining_config)
#    1050         logger.error(
#    1051             "Please check the troubleshooting guide for common errors: %s", troubleshooting
#    1052         )
#    1053         raise e
# -> 1055 self._intercept_create_request(train_request, submit, self.train.__name__)
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:6606, in Session._intercept_create_request(self, request, create, func_name)
#    6589 def _intercept_create_request(
#    6590     self,
#    6591     request: typing.Dict,
#    (...)
#    6594     # pylint: disable=unused-argument
#    6595 ):
#    6596     """This function intercepts the create job request.
#    6597
#    6598     PipelineSession inherits this Session class and will override
#    (...)
#    6604         func_name (str): the name of the function needed intercepting
#    6605     """
# -> 6606     return create(request)
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:1053, in Session.train.<locals>.submit(request)
#    1046 troubleshooting = (
#    1047     "https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-python-sdk-troubleshooting.html"
#    1048     "#sagemaker-python-sdk-troubleshooting-create-training-job"
#    1049 )
#    1050 logger.error(
#    1051     "Please check the troubleshooting guide for common errors: %s", troubleshooting
#    1052 )
# -> 1053 raise e
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:1044, in Session.train.<locals>.submit(request)
#    1042     logger.info("Creating training-job with name: %s", job_name)
#    1043     logger.debug("train request: %s", json.dumps(request, indent=4))
# -> 1044     self.sagemaker_client.create_training_job(**request)
#    1045 except Exception as e:
#    1046     troubleshooting = (
#    1047         "https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-python-sdk-troubleshooting.html"
#    1048         "#sagemaker-python-sdk-troubleshooting-create-training-job"
#    1049     )
#
# File /opt/conda/lib/python3.12/site-packages/botocore/client.py:606, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     602     raise TypeError(
#     603         f"{py_operation_name}() only accepts keyword arguments."
#     604     )
#     605 # The "self" in this scope is referring to the BaseClient.
# --> 606 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/botocore/client.py:1094, in BaseClient._make_api_call(self, operation_name, api_params)
#    1090     error_code = request_context.get(
#    1091         'error_code_override'
#    1092     ) or error_info.get("Code")
#    1093     error_class = self.exceptions.from_code(error_code)
# -> 1094     raise error_class(parsed_response, operation_name)
#    1095 else:
#    1096     return parsed_response
#
# ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateTrainingJob operation: The requested resource training-job/ml.t3.medium is not available in this region

# %%
print("\n--- Configuring SageMaker XGBoost Estimator ---")
# Retrieve the official XGBoost container image
container = sagemaker.image_uris.retrieve("xgboost", 'us-east-1', "1.7-1")

xgb_estimator = sagemaker.estimator.Estimator(
    image_uri=container,
    role=role,
    instance_count=1,
    instance_type='ml.c4.xlarge',
    output_path=f's3://{bucket}/models/xgboost-sentiment/',
    sagemaker_session=sagemaker_session
)

# Set Hyperparameters (Incorporating the EDA scale_pos_weight finding)
xgb_estimator.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    objective='binary:logistic',
    scale_pos_weight=2.92,  # Addressed class imbalance
    num_round=100
)

# Define input channels
s3_input_train = sagemaker.inputs.TrainingInput(s3_data=s3_train_path, content_type='csv')
s3_input_val = sagemaker.inputs.TrainingInput(s3_data=s3_val_path, content_type='csv')

print("Starting SageMaker Training Job...")
xgb_estimator.fit({'train': s3_input_train, 'validation': s3_input_val})
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2026-06-06-17-54-46-297
# --- Configuring SageMaker XGBoost Estimator ---
# Starting SageMaker Training Job...
# ERROR:sagemaker:Please check the troubleshooting guide for common errors: https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-python-sdk-troubleshooting.html#sagemaker-python-sdk-troubleshooting-create-training-job
# ---------------------------------------------------------------------------
# ResourceLimitExceeded                     Traceback (most recent call last)
# Cell In[28], line 31
#      28 s3_input_val = sagemaker.inputs.TrainingInput(s3_data=s3_val_path, content_type='csv')
#      30 print("Starting SageMaker Training Job...")
# ---> 31 xgb_estimator.fit({'train': s3_input_train, 'validation': s3_input_val})
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/workflow/pipeline_context.py:346, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     342         return context
#     344     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 346 return run_func(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/estimator.py:1369, in EstimatorBase.fit(self, inputs, wait, logs, job_name, experiment_config)
#    1366 self._prepare_for_training(job_name=job_name)
#    1368 experiment_config = check_and_get_run_experiment_config(experiment_config)
# -> 1369 self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#    1370 self.jobs.append(self.latest_training_job)
#    1371 forward_to_mlflow_tracking_server = False
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/estimator.py:2498, in _TrainingJob.start_new(cls, estimator, inputs, experiment_config)
#    2495 train_args = cls._get_train_args(estimator, inputs, experiment_config)
#    2497 logger.debug("Train args after processing defaults: %s", train_args)
# -> 2498 estimator.sagemaker_session.train(**train_args)
#    2500 return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:1055, in Session.train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, training_image_config, infra_check_config, container_entry_point, container_arguments, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config, environment, retry_strategy, remote_debug_config, session_chaining_config)
#    1050         logger.error(
#    1051             "Please check the troubleshooting guide for common errors: %s", troubleshooting
#    1052         )
#    1053         raise e
# -> 1055 self._intercept_create_request(train_request, submit, self.train.__name__)
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:6606, in Session._intercept_create_request(self, request, create, func_name)
#    6589 def _intercept_create_request(
#    6590     self,
#    6591     request: typing.Dict,
#    (...)
#    6594     # pylint: disable=unused-argument
#    6595 ):
#    6596     """This function intercepts the create job request.
#    6597
#    6598     PipelineSession inherits this Session class and will override
#    (...)
#    6604         func_name (str): the name of the function needed intercepting
#    6605     """
# -> 6606     return create(request)
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:1053, in Session.train.<locals>.submit(request)
#    1046 troubleshooting = (
#    1047     "https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-python-sdk-troubleshooting.html"
#    1048     "#sagemaker-python-sdk-troubleshooting-create-training-job"
#    1049 )
#    1050 logger.error(
#    1051     "Please check the troubleshooting guide for common errors: %s", troubleshooting
#    1052 )
# -> 1053 raise e
#
# File /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:1044, in Session.train.<locals>.submit(request)
#    1042     logger.info("Creating training-job with name: %s", job_name)
#    1043     logger.debug("train request: %s", json.dumps(request, indent=4))
# -> 1044     self.sagemaker_client.create_training_job(**request)
#    1045 except Exception as e:
#    1046     troubleshooting = (
#    1047         "https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-python-sdk-troubleshooting.html"
#    1048         "#sagemaker-python-sdk-troubleshooting-create-training-job"
#    1049     )
#
# File /opt/conda/lib/python3.12/site-packages/botocore/client.py:606, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     602     raise TypeError(
#     603         f"{py_operation_name}() only accepts keyword arguments."
#     604     )
#     605 # The "self" in this scope is referring to the BaseClient.
# --> 606 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/botocore/client.py:1094, in BaseClient._make_api_call(self, operation_name, api_params)
#    1090     error_code = request_context.get(
#    1091         'error_code_override'
#    1092     ) or error_info.get("Code")
#    1093     error_class = self.exceptions.from_code(error_code)
# -> 1094     raise error_class(parsed_response, operation_name)
#    1095 else:
#    1096     return parsed_response
#
# ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateTrainingJob operation: The account-level service limit 'ml.c4.xlarge for training job usage' is 0 Instances, with current utilization of 0 Instances and a request delta of 1 Instances. Please use AWS Service Quotas to request an increase for this quota. If AWS Service Quotas is not available, contact AWS support to request an increase for this quota.

# %%
import pandas as pd

# Check what's in your files
train_df = pd.read_csv(s3_train_path)
val_df   = pd.read_csv(s3_val_path)

print("Train shape:", train_df.shape)
print("Val shape:  ", val_df.shape)
print("\nTrain columns:", train_df.columns.tolist())
print("Val columns:  ", val_df.columns.tolist())
print("\nTrain head:\n", train_df.head(2))
# Out:
# Train shape: (125969, 390)
# Val shape:   (31491, 390)
#
# Train columns: ['1', '357', '1.1', '1.2', '0', '0.1', '-0.020570043', '0.023014901', '0.02584781', '0.04902307', '-0.104877815', '-0.08245782', '-0.013081983', '-0.026939657', '0.025063865', '-0.076564476', '0.051005702', '-0.04616932', '0.012192179', '-0.026117094', '0.0044918773', '-0.12214027', '0.13265437', '-0.10557165', '-0.008323222', '-0.027359638', '-0.06518504', '-0.05266582', '0.015195741', '-0.03791936', '0.013111708', '0.012209384', '0.069943726', '0.046036433', '-0.02161009', '-0.10125972', '-0.080317', '-0.008290685', '-0.07330785', '-0.039471388', '0.012859011', '0.014945003', '0.10181395', '-0.0037345018', '0.101948835', '-0.026839467', '-0.02050118', '-0.03604841', '0.081447445', '0.011315766', '-0.014337471', '-0.0455955', '-0.023423873', '0.0009882019', '-0.009934824', '-0.0047964207', '-0.0267198', '0.007112623', '0.01793475', '-0.032098148', '0.030229649', '0.034548257', '-0.08494672', '-0.0028960423', '-0.031920347', '0.021793233', '0.022446003', '0.02215074', '0.026957497', '0.007732001', '-0.027751513', '-0.11154645', '0.050563037', '0.030239103', '-0.059151515', '0.017173791', '-0.010360304', '0.02222619', '0.05592735', '-0.03951959', '0.010114569', '-0.032492876', '0.007209872', '-0.07010677', '-0.08166789', '0.017322624', '-0.03283266', '0.030731516', '-0.053882018', '-0.03772136', '-0.08367124', '0.033744603', '0.04432143', '0.002104644', '-0.06892983', '-0.016569521', '0.116731614', '-0.006290472', '-0.02865205', '-0.033767924', '0.048030585', '-0.01931695', '0.033693142', '0.061663717', '-0.01812151', '0.0078050867', '0.010921153', '0.036178313', '0.048795413', '-0.12880358', '0.08659806', '0.016972037', '-0.031579815', '0.011833997', '0.09656487', '-0.013925041', '-0.0094239535', '0.071115375', '-0.014817799', '-0.040605318', '-0.087604076', '-0.014855826', '0.06371604', '-0.00942292', '0.053405065', '-0.035141464', '0.01746693', '0.0035698658', '-0.021698434', '0.014881667', '-0.023070833', '-0.04165014', '0.07802104', '1.7997188e-34', '-0.04869828', '0.007531842', '-0.04218539', '0.023955924', '0.053447697', '-0.062143814', '-0.005633491', '-0.03449782', '-0.09909892', '0.061935358', '-0.03344174', '0.010573681', '-0.060897652', '0.033018302', '0.022917824', '-0.06067431', '-0.112927034', '-0.054877717', '-0.041422717', '-0.046902772', '-0.048333734', '0.063149735', '0.0029088561', '-0.002942139', '-0.048973903', '0.04831197', '0.0053906883', '0.0043490008', '-0.04513031', '0.017440295', '-0.018330043', '0.018056395', '0.020289335', '0.025505297', '-0.009168378', '0.06603686', '0.026633954', '-0.030140337', '0.023163615', '-0.016868202', '0.057298645', '0.03194419', '0.035927366', '0.07410173', '-0.062577166', '-0.032988973', '-0.015735775', '0.043659385', '-0.003464132', '-0.019122738', '0.0254726', '-0.02516275', '0.07828601', '0.033376694', '-0.06428204', '0.04616877', '-0.0005197226', '-0.05576237', '-0.067707874', '-0.047413033', '0.018211367', '0.010278997', '-0.0070820386', '-0.0754635', '-0.051250353', '0.035838064', '-0.06391324', '-0.021485567', '0.06930488', '-0.03090857', '0.016308794', '0.07518662', '-0.007410858', '-0.12413801', '0.021582661', '0.036052134', '0.017948808', '-0.024836887', '0.032072503', '-0.04011692', '0.10679834', '0.057104647', '0.016767573', '0.025819765', '0.006586164', '0.10861447', '0.020860964', '-0.050027177', '0.031745456', '0.05193061', '-0.04731012', '-0.003242611', '0.08730494', '-0.06493657', '0.0044251983', '-2.350527e-33', '0.04627247', '0.03290313', '0.029656155', '-0.022717487', '0.057697486', '-0.063633375', '-0.06987194', '0.01250816', '-0.039505284', '-0.12167026', '-0.049985226', '-0.01724418', '0.04206893', '-0.006725086', '-0.03864696', '0.048606794', '0.061097853', '-0.0031404595', '0.04744796', '-0.07845073', '-0.019066043', '0.025797186', '0.003999211', '0.072585665', '-0.010889877', '0.013986213', '0.053236317', '0.0005688341', '0.01020904', '-0.07613139', '0.0778312', '-0.06870611', '0.054432664', '0.010805939', '-0.03150482', '0.04861 ...
# Val columns:   ['1', '87', '0', '0.1', '0.2', '0.3', '0.0503732', '-0.0426739', '0.03435678', '0.022246836', '-0.025613781', '-0.016277883', '-0.04747423', '-0.057246763', '-0.056296587', '-0.025760483', '0.039962824', '-0.07759', '0.03684634', '-0.07878366', '0.042895198', '-0.021328432', '0.1801663', '-0.082517974', '0.044469096', '-0.063801035', '0.011955848', '0.057969447', '-0.050321203', '-0.02573512', '-0.022339303', '0.024554906', '-0.02382877', '0.040737074', '0.005687908', '0.0054116924', '0.044131096', '0.103833154', '-0.06612217', '-0.08976626', '0.042380407', '0.03625761', '0.0124979', '-0.0039728764', '0.062132362', '0.07452065', '0.048701182', '0.01722753', '0.047695186', '-0.08822592', '-0.041113276', '-0.08931969', '-0.017545115', '0.04825061', '0.10190498', '0.006243647', '0.057853695', '0.040974103', '-0.09357398', '0.015621681', '-0.025030347', '0.016865607', '-0.04105784', '-0.006652143', '0.01579739', '0.035649914', '0.03574078', '0.036853585', '-0.047537863', '0.034161273', '-0.036051445', '0.01314563', '-0.029773928', '0.048861243', '0.017742757', '-0.15795983', '-0.030447215', '-0.027030984', '0.069460645', '0.01949407', '0.039387833', '-0.020958968', '0.035823077', '0.010880561', '0.015866864', '0.060129818', '0.046850134', '0.01540704', '0.018157046', '0.026813019', '-0.05963094', '-0.051546197', '-0.026196485', '-0.004131245', '0.048286323', '0.008071305', '-0.06155637', '-0.036039695', '-0.06641583', '-0.040675286', '0.029880727', '0.016625436', '-0.04248988', '0.05560451', '-0.03833378', '0.0393761', '-0.10134481', '-0.020633714', '0.025471479', '-0.043508656', '0.07313679', '0.038522672', '-0.00897703', '0.039677743', '-0.039679952', '-0.030771319', '0.03735046', '0.024925664', '-0.017039593', '-0.039421614', '0.026675072', '0.00906073', '0.050298735', '-0.09795017', '-0.0349608', '-0.000101653735', '-0.023879694', '-0.049168248', '-0.038060606', '-0.023044167', '0.05661218', '-0.06888703', '0.057724275', '-6.874938e-33', '-0.023175482', '0.023937678', '0.046684075', '0.009758654', '0.07267892', '-0.0033601848', '-0.04812616', '-0.02599932', '-0.022132942', '-0.0053968816', '0.10448293', '-0.01715492', '-0.040787667', '0.0043403152', '0.052947383', '0.00017143384', '0.021649236', '-0.07629207', '-0.060706057', '-0.053504195', '-0.044238698', '-0.03112171', '-0.016033292', '0.018694999', '-0.10886462', '0.016575733', '0.02194133', '-0.006705227', '-0.029974015', '-0.0006158421', '-0.015003415', '0.069179036', '0.06354511', '0.0086414255', '0.0067308564', '0.039847713', '-0.00919701', '0.002194563', '-0.0055644945', '0.0035316169', '-0.034587838', '0.059444472', '-0.039364673', '0.11318633', '0.06991129', '0.03885404', '0.07379328', '-0.07822531', '0.031880062', '-0.021037377', '0.001752202', '0.002491642', '-0.053308845', '0.1342393', '-0.028865738', '0.06954765', '-0.007211006', '0.0029426976', '0.14052263', '-0.04530226', '-0.051932663', '0.09014584', '0.053379074', '-0.022207884', '0.008076175', '-0.025947452', '0.024182353', '0.02136614', '0.007258252', '-0.055692308', '0.040781416', '-0.047433037', '0.016740514', '0.0039290055', '0.039418936', '0.06606668', '-0.03466051', '-0.0029319553', '0.048433233', '-0.017642567', '0.10056063', '-0.022797294', '0.018838279', '0.06740173', '0.15473755', '-0.055073075', '-0.019806989', '-0.1389834', '-0.04064973', '-0.06987089', '-0.089364216', '0.07805144', '0.033651598', '-0.038147222', '0.016179407', '3.842381e-33', '0.059675835', '-0.040182006', '0.08794892', '0.05474009', '-0.011708699', '-0.04544749', '-0.02504454', '-0.004409399', '0.052269712', '0.08530754', '-0.16149631', '0.037444945', '0.05376025', '0.0064226077', '0.018866267', '-0.0021980167', '0.022162417', '0.021440128', '-0.05932625', '-0.05123445', '0.0069102715', '0.035887342', '-0.056212757', '0.01461311', '-0.02390173', '0.04313276', '-0.082266964', '0.016935304', '-0.08152702', '-0.0070036333', '-0.0043940507', '0.015269121', '0.03125401', '-0.058972936', '-0.018975854', '0.08245854',  ...
#
# Train head:
#     1  357  1.1  1.2  0  0.1  -0.020570043  0.023014901  0.02584781  \
# 0  1  441    1    2  1    1      0.101744     0.029844    0.091939
# 1  1  110    0    0  0    0     -0.017464    -0.000322    0.066911
#
#    0.04902307  ...  -0.024366245  0.04426262  0.0332339  0.014605477  \
# 0    0.041975  ...      0.002093    0.047855   0.038197     0.098545
# 1    0.060036  ...      0.034721   -0.005112  -0.008299    -0.060904
#
#    0.046852224  0.036654405  -0.015124896  0.103872575  -0.020878186  \
# 0     0.056272    -0.009869     -0.028172     0.045836     -0.096449
# 1     0.029551     0.046374      0.057074    -0.032161     -0.114945
#
#    0.02690986
# 0    0.012926
# 1    0.012961
#
# [2 rows x 390 columns]

# %%
import pandas as pd
import xgboost as xgb
import os

# Read without treating first row as header
train_df = pd.read_csv(s3_train_path, header=None)
val_df   = pd.read_csv(s3_val_path,   header=None)

print("Train shape:", train_df.shape)
print("Val shape:  ", val_df.shape)

# First column is the label (standard SageMaker XGBoost format)
X_train = train_df.iloc[:, 1:]
y_train = train_df.iloc[:, 0]

X_val = val_df.iloc[:, 1:]
y_val = val_df.iloc[:, 0]

dtrain = xgb.DMatrix(X_train, label=y_train)
dval   = xgb.DMatrix(X_val,   label=y_val)

params = {
    'max_depth':        5,
    'eta':              0.2,
    'gamma':            4,
    'min_child_weight': 6,
    'subsample':        0.8,
    'objective':        'binary:logistic',
    'scale_pos_weight': 2.92,
}

xgb_model = xgb.train(
    params,
    dtrain,
    num_boost_round=100,
    evals=[(dtrain, 'train'), (dval, 'validation')],
    verbose_eval=10
)

os.makedirs('models', exist_ok=True)
xgb_model.save_model('models/xgboost_model.json')
print("✅ Model trained and saved locally")
# Out:
# Train shape: (125970, 390)
# Val shape:   (31492, 390)
# [0]	train-logloss:0.52364	validation-logloss:0.52557
# [10]	train-logloss:0.33899	validation-logloss:0.34829
# [20]	train-logloss:0.28008	validation-logloss:0.29511
# [30]	train-logloss:0.24564	validation-logloss:0.26552
# [40]	train-logloss:0.22381	validation-logloss:0.24875
# [50]	train-logloss:0.20703	validation-logloss:0.23659
# [60]	train-logloss:0.19411	validation-logloss:0.22824
# [70]	train-logloss:0.18309	validation-logloss:0.22143
# [80]	train-logloss:0.17351	validation-logloss:0.21505
# [90]	train-logloss:0.16546	validation-logloss:0.21066
# [99]	train-logloss:0.15890	validation-logloss:0.20710
# ✅ Model trained and saved locally

# %%
# Load test data
test_df = pd.read_csv(s3_test_path, header=None)

X_test = test_df.iloc[:, 1:]
y_test = test_df.iloc[:, 0]

dtest = xgb.DMatrix(X_test, label=y_test)

print("Test shape:", test_df.shape)
# Out:
# Test shape: (31493, 390)

# %%
from sklearn.metrics import (
    accuracy_score, classification_report,
    confusion_matrix, roc_auc_score, roc_curve
)
import matplotlib.pyplot as plt
import seaborn as sns

# --- Predictions on TEST set ---
y_pred_proba = xgb_model.predict(dtest)
y_pred       = (y_pred_proba >= 0.5).astype(int)

# --- Core Metrics ---
acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)

print("=" * 45)
print(f"  Accuracy : {acc:.4f}")
print(f"  ROC-AUC  : {auc:.4f}")
print("=" * 45)
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Negative', 'Positive']))

# --- Confusion Matrix ---
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Neg', 'Predicted Pos'],
            yticklabels=['Actual Neg',    'Actual Pos'])
plt.title('Confusion Matrix (Test Set)')
plt.tight_layout()
plt.savefig('models/confusion_matrix.png', dpi=150)
plt.show()

# --- ROC Curve ---
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f'AUC = {auc:.4f}')
plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (Test Set)')
plt.legend()
plt.tight_layout()
plt.savefig('models/roc_curve.png', dpi=150)
plt.show()

# --- Feature Importance (Top 20) ---
scores = xgb_model.get_score(importance_type='gain')
top20  = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:20]
names, vals = zip(*top20)

plt.figure(figsize=(8, 5))
plt.barh(names[::-1], vals[::-1])
plt.xlabel('Gain')
plt.title('Top 20 Feature Importances')
plt.tight_layout()
plt.savefig('models/feature_importance.png', dpi=150)
plt.show()
# Out:
# =============================================
#   Accuracy : 0.9137
#   ROC-AUC  : 0.9713
# =============================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.72      0.81      8026
#     Positive       0.91      0.98      0.94     23467
#
#     accuracy                           0.91     31493
#    macro avg       0.92      0.85      0.88     31493
# weighted avg       0.91      0.91      0.91     31493
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
import shap

explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_test.iloc[:500])  # sample 500 rows

shap.summary_plot(shap_values, X_test.iloc[:500])

# %%
# !pip install shap --quiet
